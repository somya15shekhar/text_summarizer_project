# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# ## Data Exploration

# %%
data = pd.read_csv(r"C:\Users\Somya Shekhar\Desktop\text_summarizer_project\data\BBC News Train.csv")
df = pd.DataFrame(data)
df.head()

# %%
text = df['Text'].tolist()
text[:5]

# %%
import nltk
nltk.download('punkt_tab')

# %% [markdown]
# ## Text Preprocessing

# %%
# replace, strip whitespaces
# text is a list of strings
text = [t.replace('\n', ' ').strip() for t in text]
text[:5]

# %%
from model.summarizer import generate_summary
df['summary'] = df['Text'].apply(generate_summary)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 2
#       1 from model.summarizer import generate_summary
# ----> 2 df['summary'] = df['Text'].apply(generate_summary)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# File c:\Users\Somya Shekhar\Desktop\text_summarizer_project\model\summarizer.py:30, in generate_summary(article_text)
#      27     article_text = article_text[:3000]
#      29 # Summarize
# ---> 30 summary = summarizer(article_text, max_length=150, min_length=40, do_sample=False)
#      31 raw_summary = summary[0]['summary_text']
#      33 # Grammar correction (optional step)
#
# File c:\Users\Somya Shekhar\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\pipelines\text2text_generation.py:299, in SummarizationPipeline.__call__(self, *args, **kwargs)
#     275 def __call__(self, *args, **kwargs):
#     276     r"""
#     277     Summarize the text(s) given as inputs.
#     278
#    (...)
#     297           ids of the summary.
#     298     """
# --> 299     return super().__call__(*args, **kwargs)
#
# File c:\Users\Somya Shekhar\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\pipelines\text2text_generation.py:187, in Text2TextGenerationPipeline.__call__(self, *args, **kwargs)
#     158 def __call__(self, *args: Union[str, list[str]], **kwargs: Any) -> list[dict[str, str]]:
#     159     r"""
#     160     Generate the output text(s) using text(s) given as inputs.
#     161
#    (...)
#     184           ids of the generated text.
#     185     """
# --> 187     result = super().__call__(*args, **kwargs)
#     188     if (
#     189         isinstance(args[0], list)
#     190         and all(isinstance(el, str) for el in args[0])
#     191         and all(len(res) == 1 for res in result)
#     192     ):
#     193         return [res[0] for res in result]
#
# File c:\Users\Somya Shekhar\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\pipelines\base.py:1464, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1456     return next(
#    1457         iter(
#    1458             self.get_iterator(
#    (...)
#    1461         )
#    1462     )
#    1463 else:
# -> 1464     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File c:\Users\Somya Shekhar\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\pipelines\base.py:1471, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1469 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1470     model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1471     model_outputs = self.forward(model_inputs, **forward_params)
#    1472     outputs = self.postprocess(model_outputs, **postprocess_params)
#    1473     return outputs
#
# File c:\Users\Somya Shekhar\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\pipelines\base.py:1371, in Pipeline.forward(self, model_inputs, **forward_params)
#    1369     with inference_context():
#    1370         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1371         model_outputs = self._forward(model_inputs, **forward_params)
#    1372         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1373 else:
#
# File c:\Users\Somya Shekhar\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\pipelines\text2text_generation.py:216, in Text2TextGenerationPipeline._forward(self, model_inputs, **generate_kwargs)
#     213 if "generation_config" not in generate_kwargs:
#     214     generate_kwargs["generation_config"] = self.generation_config
# --> 216 output_ids = self.model.generate(**model_inputs, **generate_kwargs)
#     217 out_b = output_ids.shape[0]
#     218 if self.framework == "pt":
#
# File c:\Users\Somya Shekhar\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File c:\Users\Somya Shekhar\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\generation\utils.py:2644, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, use_model_defaults, custom_generate, **kwargs)
#    2637     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2638         input_ids=input_ids,
#    2639         expand_size=generation_config.num_beams,
#    2640         is_encoder_decoder=self.config.is_encoder_decoder,
#    2641         **model_kwargs,
#    2642     )
#    2643     # 12. run beam sample
# -> 2644     result = self._beam_search(
#    2645         input_ids,
#    2646         logits_processor=prepared_logits_processor,
#    2647         stopping_criteria=prepared_stopping_criteria,
#    2648         generation_config=generation_config,
#    2649         synced_gpus=synced_gpus,
#    2650         **model_kwargs,
#    2651     )
#    2653 elif generation_mode == GenerationMode.GROUP_BEAM_SEARCH:
#    2654     logger.warning_once(
#    2655         "Group Beam Search is scheduled to be moved to a `custom_generate` repository in v4.55.0. "
#    2656         "To prevent loss of backward compatibility, add `trust_remote_code=True` to your `generate` call."
#    2657     )
#
# File c:\Users\Somya Shekhar\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\generation\utils.py:4185, in GenerationMixin._beam_search(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, **model_kwargs)
#    4180 # g. Prepare remaining data for the next iteration, including computing the stopping condition for
#    4181 # beam search as a whole (as opposed to individual beams, i.e. `stopping_criteria`)
#    4182
#    4183 # pluck the cache from the beam indices that will be used in the next iteration
#    4184 if model_kwargs.get("past_key_values", None) is not None:
# -> 4185     model_kwargs["past_key_values"] = self._temporary_reorder_cache(
#    4186         past_key_values=model_kwargs["past_key_values"],
#    4187         beam_idx=self._flatten_beam_dim(running_beam_indices[..., cur_len - decoder_prompt_len]),
#    4188     )
#    4190 cur_len = cur_len + 1
#    4191 this_peer_finished = not self._beam_search_has_unfinished_sequences(
#    4192     running_beam_scores,
#    4193     beam_scores,
#    (...)
#    4200     length_penalty,
#    4201 )
#
# File c:\Users\Somya Shekhar\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\generation\utils.py:3724, in GenerationMixin._temporary_reorder_cache(self, past_key_values, beam_idx)
#    3721     past_key_values = DynamicCache.from_legacy_cache(past_key_values)
#    3722 # Standard code path: use the `Cache.reorder_cache`
#    3723 else:
# -> 3724     past_key_values.reorder_cache(beam_idx)
#    3725 return past_key_values
#
# File c:\Users\Somya Shekhar\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\cache_utils.py:1479, in EncoderDecoderCache.reorder_cache(self, beam_idx)
#    1477 """Reorders the cache for beam search, given the selected beam indices."""
#    1478 self.self_attention_cache.reorder_cache(beam_idx)
# -> 1479 self.cross_attention_cache.reorder_cache(beam_idx)
#
# File c:\Users\Somya Shekhar\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\cache_utils.py:183, in Cache.reorder_cache(self, beam_idx)
#     181 if self.key_cache[layer_idx].numel():
#     182     device = self.key_cache[layer_idx].device
# --> 183     self.key_cache[layer_idx] = self.key_cache[layer_idx].index_select(0, beam_idx.to(device))
#     184 if self.value_cache[layer_idx].numel():
#     185     device = self.value_cache[layer_idx].device
#
# KeyboardInterrupt:
